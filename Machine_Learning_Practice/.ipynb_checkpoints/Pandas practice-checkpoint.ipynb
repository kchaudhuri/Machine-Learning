# %%
import pandas as pd

# %%
dd1 = {'Apples':[30], 'Bananas':[21]}

# %%
#Dataframe is a table
DataFrame = pd.DataFrame(data = dd1)

# %%
DataFrame
# Out:
#    Apples  Bananas
# 0      30       21

# %%
dd1 = {'Apples':[35, 41], 'Bananas':[21, 34]}
DataFrame = pd.DataFrame(data = dd1, index = ['2017 Sales', '2018 Sales'])

# %%
DataFrame
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
#Series is a Pandas list
Series = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index = ['Flour', 'Milk', 'Eggs', 'Spam'], name = 'Dinner')

# %%
Series
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
#Reading CSV
csvtodf = pd.read_csv("../input/wine-reviews/winemag-data_first150k.csv", index_col = 0)

# %%
#Reading Excel file sheet wise
xlstodf = pd.read_excel("../input/publicassistance/xls_files_all/WICAgencies2014ytd.xls", sheet_name='Pregnant Women Participating')

# %%
poultry = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])

# %%
poultry.to_csv("poultry.csv")

# %%
#Reading data from sqlite3 to dataframe
import sqlite3
conn = sqlite3.connect("../input/188-million-us-wildfires/FPA_FOD_20170508.sqlite")
sqltodf = pd.read_sql_query("SELECT * FROM artists", conn)

# %%
import pandas as pd
import seaborn as sns

# %%
rev = pd.read_csv("C:/Users/Kaustubh Chaudhuri/Documents/Datasets/wine-reviews/winemag-data_first150k.csv", index_col=0)

# %%
rev.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
rev.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
#selecting column
rev.description
# Out:
# 0         This tremendous 100% varietal wine hails from ...
# 1         Ripe aromas of fig, blackberry and cassis are ...
# 2         Mac Watson honors the memory of a wine once ma...
# 3         This spent 20 months in 30% new French oak, an...
# 4         This is the top wine from La Bégude, named aft...
# 5         Deep, dense and pure from the opening bell, th...
# 6         Slightly gritty black-fruit aromas include a s...
# 7         Lush cedary black-fruit aromas are luxe and of...
# 8         This re-named vineyard was formerly bottled as...
# 9         The producer sources from two blocks of the vi...
# 10        Elegance, complexity and structure come togeth...
# 11        From 18-year-old vines, this supple well-balan...
# 12        A standout even in this terrific lineup of 201...
# 13        This wine is in peak condition. The tannins an...
# 14        With its sophisticated mix of mineral, acid an...
# 15        First made in 2006, this succulent luscious Ch...
# ...

# %%
rev.description[0]
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
#selecting row
rev.loc[0]
rev.iloc[0]
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                        235
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %%
rev.description[:10]
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: object

# %%
#selecting selected rows from df
rev.loc[[1,2,3,5,8]]
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# ...

# %%
#selecting particular rows and columns
rev.loc[[0,1,10,100],['country','province','region_1','region_2']]
# Out:
#     country            province     region_1     region_2
# 0        US          California  Napa Valley         Napa
# 1     Spain      Northern Spain         Toro          NaN
# 10    Italy  Northeastern Italy       Collio          NaN
# 100      US          California  South Coast  South Coast

# %%
#selecting range
rev.loc[0:99,['country','variety']] 
rev.iloc[:100,[0,8]] #only indexes
# Out:
#         country               variety
# 0            US    Cabernet Sauvignon
# 1         Spain         Tinta de Toro
# 2            US       Sauvignon Blanc
# 3            US            Pinot Noir
# 4        France    Provence red blend
# 5         Spain         Tinta de Toro
# 6         Spain         Tinta de Toro
# 7         Spain         Tinta de Toro
# 8            US            Pinot Noir
# 9            US            Pinot Noir
# 10        Italy              Friulano
# 11           US            Pinot Noir
# 12           US            Pinot Noir
# 13       France                Tannat
# 14           US            Pinot Noir
# 15           US            Chardonnay
# 16           US    Cabernet Sauvignon
# 17        Spain           Tempranillo
# 18       France                Malbec
# 19           US            Pinot Noir
# 20           US                  Rosé
# 21        Spain     Tempranillo Blend
# 22        Spain         Tinta de Toro
# 23           US            Chardonnay
# ...

# %%
#selecting rows with respect to values
rev.loc[rev.country == 'Italy']
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# 39       Italy  This bright, savory wine delivers aromas and f...
# 43       Italy  Aromas of dark-skinned berry, rose and wild he...
# 45       Italy  A blend of 90% Sangiovese and 10% Canaiolo, th...
# 46       Italy  Sunbaked earth, ripe berry, baking spice and a...
# 48       Italy  Ripe dark-skinned berry, forest floor and cook...
# 50       Italy  This robust red opens with aromas of espresso,...
# 59       Italy  This savory blend of 40% Merlot, 30% Cabernet ...
# 72       Italy  This offers aromas of red rose, wild berry, da...
# ...

# %%
#not selecting NaNs
rev.loc[rev.region_2.notnull()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# 11          US  From 18-year-old vines, this supple well-balan...
# 12          US  A standout even in this terrific lineup of 201...
# 14          US  With its sophisticated mix of mineral, acid an...
# 15          US  First made in 2006, this succulent luscious Ch...
# 16          US  This blockbuster, powerhouse of a wine suggest...
# 19          US  This fresh and lively medium-bodied wine is be...
# 20          US  Heitz has made this stellar rosé from the rare...
# 23          US  The apogee of this ambitious winery's white wi...
# ...

# %%
#selecting NaNs
rev.loc[rev.region_2.isnull()]
# Out:
#             country                                        description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 10            Italy  Elegance, complexity and structure come togeth...
# 13           France  This wine is in peak condition. The tannins an...
# 17            Spain  Nicely oaked blackberry, licorice, vanilla and...
# 18           France  Coming from a seven-acre vineyard named after ...
# 21            Spain  Alluring, complex and powerful aromas of grill...
# 22            Spain  Tarry blackberry and cheesy oak aromas are app...
# 25      New Zealand  Yields were down in 2015, but intensity is up,...
# ...

# %%
rev.points
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
# 5         95
# 6         95
# 7         95
# 8         95
# 9         95
# 10        95
# 11        95
# 12        95
# 13        95
# 14        95
# 15        95
# 16        95
# 17        95
# 18        95
# 19        95
# 20        95
# 21        95
# 22        95
# 23        95
# 24        95
# 25        94
# 26        94
# 27        94
# 28        94
# 29        94
#           ..
# 150900    81
# 150901    81
# 150902    81
# 150903    81
# 150904    81
# 150905    80
# 150906    93
# 150907    92
# 150908    90
# 150909    89
# 150910    89
# 150911    87
# 150912    87
# 150913    94
# 150914    94
# 150915    93
# 150916    93
# 150917    92
# 150918    92
# 150919    91
# 150920    91
# 150921    91
# 150922    91
# 150923    91
# 150924    91
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
#selecting column points for the last 1000 rows
rev.iloc[-1000:, 3]
# Out:
# 149930    85
# 149931    85
# 149932    84
# 149933    84
# 149934    84
# 149935    84
# 149936    84
# 149937    84
# 149938    84
# 149939    84
# 149940    88
# 149941    88
# 149942    88
# 149943    88
# 149944    88
# 149945    87
# 149946    87
# 149947    87
# 149948    87
# 149949    87
# 149950    87
# 149951    87
# 149952    87
# 149953    87
# 149954    87
# 149955    87
# 149956    87
# 149957    87
# 149958    87
# 149959    87
#           ..
# 150900    81
# 150901    81
# 150902    81
# 150903    81
# 150904    81
# 150905    80
# 150906    93
# 150907    92
# 150908    90
# 150909    89
# 150910    89
# 150911    87
# 150912    87
# 150913    94
# 150914    94
# 150915    93
# 150916    93
# 150917    92
# 150918    92
# 150919    91
# 150920    91
# 150921    91
# 150922    91
# 150923    91
# 150924    91
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 1000, dtype: int64

# %%
#Select the `points` column, but only for wines made in Italy
rev.points[rev.country == 'Italy']
# Out:
# 10        95
# 32        90
# 35        90
# 37        90
# 38        90
# 39        90
# 43        90
# 45        90
# 46        90
# 48        90
# 50        90
# 59        90
# 72        91
# 79        91
# 82        91
# 83        91
# 84        91
# 85        91
# 92        86
# 102       86
# 129       90
# 130       90
# 166       89
# 167       89
# 176       89
# 177       89
# 211       93
# 213       93
# 217       93
# 224       93
#           ..
# 150515    83
# 150516    83
# 150518    83
# 150521    83
# 150533    83
# 150534    83
# 150535    83
# 150537    83
# 150538    83
# 150543    82
# 150549    82
# 150552    82
# 150556    81
# 150557    81
# 150576    92
# 150614    89
# 150691    86
# 150734    84
# 150767    92
# 150776    91
# 150798    89
# 150799    89
# 150804    88
# 150823    87
# 150824    87
# 150920    91
# 150922    91
# 150925    91
# 150927    91
# 150929    90
# Name: points, Length: 23478, dtype: int64

# %%
import pandas as pd
pd.set_option('max_rows', 5)
import numpy as np

reviews = pd.read_csv("C:/Users/Kaustubh Chaudhuri/Documents/Datasets/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# describe() row indexes
reviews.describe()['points'].index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
# taking out the median
reviews.points.median()
# Out:
# 88.0

# %%
# retrieving all the possible values of a column
reviews.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
# No of counts for each value
reviews.country.value_counts()
# Out:
# US        54504
# France    22093
#           ...
# China         1
# Egypt         1
# Name: country, Length: 43, dtype: int64

# %%
# Altering values in a column
md = reviews.price.median()
a4 = reviews.price - md
a4
# Out:
# 0          NaN
# 1        -10.0
#           ...
# 129969     7.0
# 129970    -4.0
# Name: price, Length: 129971, dtype: float64

# %%
# which wine has the highest points-to-price ratio in the dataset
reviews.title[(reviews.points / reviews.price).idxmax()]
# Out:
# 'Bandit NV Merlot (California)'

# %%
# Is a wine more likely to be "tropical" or "fruity"? Create a `Series` counting how many times each of these two words appears in the `description` column in the dataset
tropical_wine = reviews.description.map(lambda r: "tropical" in r).value_counts()
fruity_wine = reviews.description.map(lambda r: "fruity" in r).value_counts()
pd.Series([tropical_wine[True], fruity_wine[True]], index=['tropical', 'fruity'])
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
# Create a `Series` whose index consists of strings of the form `"<Country> - <Wine Variety>"`. For example, a pinot noir produced in the US should map to `"US - Pinot Noir"`. 
# The values should be counts of how many times the given wine appears in the dataset. Drop any reviews with incomplete `country` or `variety` data.
ans = reviews.loc[(reviews.country.notnull()) & (reviews.variety.notnull())]
ans = ans.apply(lambda srs: srs.country + " - " + srs.variety, axis='columns')
ans.value_counts()
# Out:
# US - Pinot Noir                   9885
# US - Cabernet Sauvignon           7315
#                                   ...
# France - Malbec-Cabernet Franc       1
# Spain - Premsal                      1
# Length: 1612, dtype: int64

# %%
# Counting the values
reviews.points.value_counts()
# Out:
# 88     17207
# 87     16933
#        ...
# 99        33
# 100       19
# Name: points, Length: 21, dtype: int64

# %%
# Grouping 
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is
# the maximum number of points a wine costing that much was given in a review. Sort the valeus by price, ascending (so that `4.0`
# dollars is at the top and `3300.0` dollars is at the bottom).
best_wine = reviews.groupby('price').points.max()

# %%
x = lambda a:a+10

# %%
x
# Out:
# <function __main__.<lambda>>

# %%
x(5)
# Out:
# 15

# %%
sqr = lambda a:a*a

# %%
sqr(4)
# Out:
# 16

# %%
for i in range(1000):
    print(sqr(i))
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000
# 10201
# 10404
# 10609
# 10816
# 11025
# 11236
# 11449
# 11664
# 11881
# 12100
# 12321
# 12544
# 12769
# 12996
# 13225
# 13456
# 13689
# 13924
# 14161
# 14400
# 14641
# 14884
# 15129
# 15376
# 15625
# 15876
# 16129
# 16384
# 16641
# 16900
# 17161
# 17424
# 17689
# 17956
# 18225
# 18496
# 18769
# 19044
# 19321
# 19600
# 19881
# 20164
# ...

# %%
add = lambda a,b:a+b

# %%
add(3,4)
# Out:
# 7

# %%
def myfunc(n):
    return lambda a : a * n

# %%
myfunc(3)
# Out:
# <function __main__.myfunc.<locals>.<lambda>>

# %%
squares = [n**2 for n in range(10)]

# %%
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
